# %%
# Core Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from scipy import stats
from scipy.stats import randint, uniform

# %%
import tensorflow as tf

# %% [markdown]
# ## IMPORT & EXPLORE

# %% [markdown]
# #### FUNCTIONS

# %%
def display_examples(images, labels=None, reconstructed_images=None, num_examples=5, mode="single"):
    """
    Display original images (and optionally compare with reconstructed ones).

    Parameters:
    - images: List or array of original images.
    - labels: List of labels (optional).
    - reconstructed_images: List or array of reconstructed images (optional).
    - num_examples: Number of examples to display.
    - mode: "single" to show only originals, "compare" to show originals vs reconstructed.
    """
    plt.figure(figsize=(num_examples * 2, 4 if mode == "single" else 6))

    for i in range(num_examples):
        # Original image
        ax = plt.subplot(2 if mode == "compare" else 1, num_examples, i + 1)
        ax.imshow(images[i])
        if labels is not None:
            ax.set_title(f"Label: {labels[i]}")
        ax.axis("off")

        # Reconstructed image (only in compare mode)
        if mode == "compare" and reconstructed_images is not None:
            ax = plt.subplot(2, num_examples, i + 1 + num_examples)
            ax.imshow(reconstructed_images[i])
            ax.set_title("Reconstructed")
            ax.axis("off")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### DATA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#### COLAB VERSION

flip_book_images = np.load("/content/drive/MyDrive/Data Science/flip_book/data/flip_book_images.npz")

flip_book_images_train = flip_book_images['train']

flip_book_images_test = flip_book_images['test']

flip_book_images_validation = flip_book_images['validation']

# %%
display_examples( images = flip_book_images_validation[42:],
                  labels = ['1','2','3'],
                  mode = 'single',
                  num_examples = 3 )

# %% [markdown]
# ## MODEL BUILD

# %%
from tensorflow.keras import layers, models, optimizers, callbacks, applications, losses

# %% [markdown]
# #### STRUCTURE

# %%
book_image_autoencoder = models.Sequential( [

      #Encoder
      layers.Conv2D( filters = 64,
                     kernel_size = (3,3),
                     activation = 'relu',
                     padding = 'same'),
      layers.MaxPool2D( pool_size = (2,2) ),

      layers.Conv2D( filters = 32,
                     kernel_size = (3,3),
                     activation = 'relu',
                     padding = 'same'),
      layers.MaxPool2D( pool_size = (2,2) ),

      layers.Conv2D( filters = 16,
                     kernel_size = (3,3),
                     activation = 'relu',
                     padding = 'same'),
      layers.MaxPool2D( pool_size = (2,2) ),


      #Decoder
      layers.Conv2D( filters = 16,
                     kernel_size = (3,3),
                     activation = 'relu',
                     padding = 'same'),
      layers.UpSampling2D( size = (2,2) ),

      layers.Conv2D( filters = 32,
                     kernel_size = (3,3),
                     activation = 'relu',
                     padding = 'same'),
      layers.UpSampling2D( size = (2,2) ),

      layers.Conv2D( filters = 64,
                     kernel_size = (3,3),
                     activation = 'relu',
                     padding = 'same'),
      layers.UpSampling2D( size = (2,2) ),

      layers.Conv2D( filters = 3,
                     kernel_size = (3,3),
                     activation = 'sigmoid',
                     padding = 'same')

 ] )

# %%
book_image_autoencoder.build( input_shape = (None, 224, 224, 3) )

# %%
book_image_autoencoder.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_7 (Conv2D)               │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 112, 112, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 56, 56, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 28, 28, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 28, 28, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_3 (UpSampling2D)  │ (None, 56, 56, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 56, 56, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_4 (UpSampling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_5 (UpSampling2D)  │ (None, 224, 224, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 224, 224, 3)    │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,067 (203.39 KB)
#  Trainable params: 52,067 (203.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### COMPILE

# %%
book_image_autoencoder.compile( optimizer = optimizers.Adam(),
                                loss = losses.MeanSquaredError() )


book_image_autoencoder_early_stopping = callbacks.EarlyStopping( patience = 75,
                                                                 monitor = 'val_loss',
                                                                 restore_best_weights = True )

# %% [markdown]
# #### TRAIN

# %%
# Get half of each set
half_train = len(flip_book_images_train) // 2
half_val = len(flip_book_images_validation) // 2

# Train using only half of each set
book_image_autoencoder_training_history = book_image_autoencoder.fit(
                                                                      x = tf.stack(flip_book_images_train[:half_train]),
                                                                      y = tf.stack(flip_book_images_train[:half_train]),
                                                                      validation_data = (
                                                                          tf.stack(flip_book_images_validation[:half_val]),
                                                                          tf.stack(flip_book_images_validation[:half_val])
                                                                      ),
                                                                      epochs = 175,
                                                                      callbacks = [book_image_autoencoder_early_stopping],
                                                                      batch_size = 32,
                                                                      verbose = 1
                                                                     )
# Out:
# Epoch 1/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 23s 205ms/step - loss: 0.0846 - val_loss: 0.0373
# Epoch 2/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 26s 123ms/step - loss: 0.0344 - val_loss: 0.0281
# Epoch 3/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0274 - val_loss: 0.0257
# Epoch 4/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0259 - val_loss: 0.0243
# Epoch 5/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - loss: 0.0237 - val_loss: 0.0222
# Epoch 6/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0220 - val_loss: 0.0204
# Epoch 7/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0203 - val_loss: 0.0199
# Epoch 8/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 0.0197 - val_loss: 0.0197
# Epoch 9/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0197 - val_loss: 0.0189
# Epoch 10/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0189 - val_loss: 0.0185
# Epoch 11/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0191 - val_loss: 0.0182
# Epoch 12/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0190 - val_loss: 0.0181
# Epoch 13/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0183 - val_loss: 0.0177
# Epoch 14/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0184 - val_loss: 0.0176
# Epoch 15/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0183 - val_loss: 0.0177
# Epoch 16/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0178 - val_loss: 0.0172
# Epoch 17/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0177 - val_loss: 0.0171
# Epoch 18/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0178 - val_loss: 0.0172
# Epoch 19/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0175 - val_loss: 0.0169
# Epoch 20/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 21/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - loss: 0.0172 - val_loss: 0.0166
# Epoch 22/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0176 - val_loss: 0.0166
# Epoch 23/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0169 - val_loss: 0.0165
# Epoch 24/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 25/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 0.0167 - val_loss: 0.0166
# Epoch 26/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 27/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0167 - val_loss: 0.0163
# Epoch 28/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 29/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - loss: 0.0166 - val_loss: 0.0159
# Epoch 30/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0165 - val_loss: 0.0160
# Epoch 31/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0165 - val_loss: 0.0167
# Epoch 32/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - loss: 0.0165 - val_loss: 0.0158
# Epoch 33/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0160 - val_loss: 0.0158
# Epoch 34/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0162 - val_loss: 0.0156
# Epoch 35/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0159 - val_loss: 0.0155
# Epoch 36/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0164 - val_loss: 0.0155
# Epoch 37/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0163 - val_loss: 0.0154
# Epoch 38/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0155 - val_loss: 0.0153
# Epoch 39/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0158 - val_loss: 0.0153
# Epoch 40/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 41/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0157 - val_loss: 0.0152
# Epoch 42/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 0.0152 - val_loss: 0.0151
# Epoch 43/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0157 - val_loss: 0.0155
# Epoch 44/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0157 - val_loss: 0.0150
# Epoch 45/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0154 - val_loss: 0.0150
# Epoch 46/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0153 - val_loss: 0.0150
# Epoch 47/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - loss: 0.0153 - val_loss: 0.0150
# Epoch 48/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0150 - val_loss: 0.0149
# Epoch 49/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0151 - val_loss: 0.0149
# Epoch 50/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0152 - val_loss: 0.0148
# Epoch 51/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0151 - val_loss: 0.0147
# Epoch 52/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0152 - val_loss: 0.0148
# Epoch 53/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 0.0154 - val_loss: 0.0145
# Epoch 54/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0154 - val_loss: 0.0147
# Epoch 55/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0148 - val_loss: 0.0145
# Epoch 56/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0150 - val_loss: 0.0161
# Epoch 57/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0153 - val_loss: 0.0144
# Epoch 58/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0148 - val_loss: 0.0144
# Epoch 59/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0148 - val_loss: 0.0147
# Epoch 60/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0149 - val_loss: 0.0147
# Epoch 61/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0147 - val_loss: 0.0142
# Epoch 62/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0148 - val_loss: 0.0146
# Epoch 63/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0147 - val_loss: 0.0143
# Epoch 64/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0144 - val_loss: 0.0142
# Epoch 65/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 0.0150 - val_loss: 0.0144
# Epoch 66/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0145 - val_loss: 0.0140
# Epoch 67/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0147 - val_loss: 0.0141
# Epoch 68/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0147 - val_loss: 0.0140
# Epoch 69/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0141 - val_loss: 0.0140
# Epoch 70/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0145 - val_loss: 0.0140
# Epoch 71/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - loss: 0.0145 - val_loss: 0.0139
# Epoch 72/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0143 - val_loss: 0.0138
# Epoch 73/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0145 - val_loss: 0.0141
# Epoch 74/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0142 - val_loss: 0.0139
# Epoch 75/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0148 - val_loss: 0.0138
# Epoch 76/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0142 - val_loss: 0.0139
# Epoch 77/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 0.0140 - val_loss: 0.0137
# Epoch 78/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 0.0141 - val_loss: 0.0138
# Epoch 79/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0139 - val_loss: 0.0137
# Epoch 80/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0140 - val_loss: 0.0136
# Epoch 81/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0141 - val_loss: 0.0136
# Epoch 82/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 0.0136 - val_loss: 0.0137
# Epoch 83/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0140 - val_loss: 0.0136
# Epoch 84/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0140 - val_loss: 0.0135
# Epoch 85/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0137 - val_loss: 0.0135
# Epoch 86/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0139 - val_loss: 0.0134
# Epoch 87/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0145 - val_loss: 0.0134
# Epoch 88/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0136 - val_loss: 0.0135
# Epoch 89/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0137 - val_loss: 0.0137
# Epoch 90/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0139 - val_loss: 0.0133
# Epoch 91/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0137 - val_loss: 0.0135
# Epoch 92/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0136 - val_loss: 0.0132
# Epoch 93/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0135 - val_loss: 0.0133
# Epoch 94/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0136 - val_loss: 0.0133
# Epoch 95/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0135 - val_loss: 0.0133
# Epoch 96/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0140 - val_loss: 0.0131
# Epoch 97/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - loss: 0.0135 - val_loss: 0.0131
# Epoch 98/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0136 - val_loss: 0.0134
# Epoch 99/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0136 - val_loss: 0.0135
# Epoch 100/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0133 - val_loss: 0.0130
# Epoch 101/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0138 - val_loss: 0.0133
# Epoch 102/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 0.0132 - val_loss: 0.0130
# Epoch 103/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 0.0134 - val_loss: 0.0136
# Epoch 104/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0134 - val_loss: 0.0130
# Epoch 105/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0129 - val_loss: 0.0132
# Epoch 106/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0136 - val_loss: 0.0130
# Epoch 107/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0131 - val_loss: 0.0130
# Epoch 108/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0131 - val_loss: 0.0129
# Epoch 109/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0131 - val_loss: 0.0138
# Epoch 110/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0135 - val_loss: 0.0129
# Epoch 111/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0132 - val_loss: 0.0128
# Epoch 112/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0130 - val_loss: 0.0128
# Epoch 113/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0131 - val_loss: 0.0128
# Epoch 114/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 0.0133 - val_loss: 0.0128
# Epoch 115/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 0.0133 - val_loss: 0.0132
# Epoch 116/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0129 - val_loss: 0.0127
# Epoch 117/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0129 - val_loss: 0.0131
# Epoch 118/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - loss: 0.0135 - val_loss: 0.0126
# Epoch 119/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0130 - val_loss: 0.0126
# Epoch 120/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0128 - val_loss: 0.0127
# Epoch 121/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0130 - val_loss: 0.0126
# Epoch 122/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0130 - val_loss: 0.0126
# Epoch 123/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0131 - val_loss: 0.0126
# Epoch 124/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0125 - val_loss: 0.0126
# Epoch 125/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - loss: 0.0131 - val_loss: 0.0126
# Epoch 126/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0130 - val_loss: 0.0125
# Epoch 127/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0129 - val_loss: 0.0125
# Epoch 128/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0131 - val_loss: 0.0126
# Epoch 129/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 130/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0126 - val_loss: 0.0124
# Epoch 131/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - loss: 0.0127 - val_loss: 0.0126
# Epoch 132/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 133/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0126 - val_loss: 0.0124
# Epoch 134/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - loss: 0.0125 - val_loss: 0.0128
# Epoch 135/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0128 - val_loss: 0.0125
# Epoch 136/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - loss: 0.0130 - val_loss: 0.0123
# Epoch 137/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0128 - val_loss: 0.0124
# Epoch 138/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0127 - val_loss: 0.0123
# Epoch 139/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0125 - val_loss: 0.0123
# Epoch 140/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0124 - val_loss: 0.0124
# Epoch 141/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0128 - val_loss: 0.0124
# Epoch 142/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 0.0124 - val_loss: 0.0123
# Epoch 143/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0127 - val_loss: 0.0126
# Epoch 144/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0128 - val_loss: 0.0122
# Epoch 145/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0127 - val_loss: 0.0122
# Epoch 146/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0124 - val_loss: 0.0122
# Epoch 147/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0125 - val_loss: 0.0122
# Epoch 148/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0127 - val_loss: 0.0130
# Epoch 149/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.0128 - val_loss: 0.0121
# Epoch 150/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0124 - val_loss: 0.0124
# Epoch 151/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - loss: 0.0128 - val_loss: 0.0123
# Epoch 152/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0123 - val_loss: 0.0121
# Epoch 153/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0124 - val_loss: 0.0121
# Epoch 154/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0128 - val_loss: 0.0131
# Epoch 155/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - loss: 0.0127 - val_loss: 0.0120
# Epoch 156/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 0.0123 - val_loss: 0.0125
# Epoch 157/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0125 - val_loss: 0.0120
# Epoch 158/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.0122 - val_loss: 0.0120
# Epoch 159/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 0.0121 - val_loss: 0.0120
# Epoch 160/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - loss: 0.0124 - val_loss: 0.0125
# Epoch 161/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0122 - val_loss: 0.0120
# Epoch 162/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - loss: 0.0122 - val_loss: 0.0119
# Epoch 163/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 0.0123 - val_loss: 0.0120
# Epoch 164/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - loss: 0.0121 - val_loss: 0.0123
# Epoch 165/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 166/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - loss: 0.0123 - val_loss: 0.0123
# Epoch 167/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - loss: 0.0124 - val_loss: 0.0119
# Epoch 168/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - loss: 0.0123 - val_loss: 0.0119
# Epoch 169/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 170/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0122 - val_loss: 0.0119
# Epoch 171/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0124 - val_loss: 0.0119
# Epoch 172/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - loss: 0.0123 - val_loss: 0.0124
# Epoch 173/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 0.0125 - val_loss: 0.0118
# Epoch 174/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - loss: 0.0121 - val_loss: 0.0118
# Epoch 175/175
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 0.0123 - val_loss: 0.0119

# %% [markdown]
# #### EVALUATE

# %%
book_image_autoencoder_test_predictions = book_image_autoencoder.predict( tf.stack(flip_book_images_test) )
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step

# %%
display_examples_ext( images = flip_book_images_test,
                      reconstructed_images = book_image_autoencoder_test_predictions,
                      num_examples = 7,
                      mode = 'compare' )

# %% [markdown]
# #### EMBEDER

# %%
encode_layers = []

for layer in book_image_autoencoder.layers:

  encode_layers.append(layer)

  if layer.name == "max_pooling2d_5":
    break

# %%
book_image_encoder = models.Sequential( [*encode_layers,
                                         layers.GlobalAveragePooling2D()] )

# %%
book_image_encoder.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_7 (Conv2D)               │ (32, 224, 224, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (32, 112, 112, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (32, 112, 112, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (32, 56, 56, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (32, 56, 56, 16)       │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (32, 28, 28, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ ?                      │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,880 (97.19 KB)
#  Trainable params: 24,880 (97.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
book_image_encoder_test_embeddings = book_image_encoder.predict( tf.stack(flip_book_images_test) )
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step

# %%
book_image_encoder_test_embeddings.shape
# Out:
# (1000, 16)

# %% [markdown]
# #### SAVE

# %%
book_image_autoencoder.save("book_image_autoencoder52t.keras")

# %%
book_image_encoder.save("book_image_encoder24t.keras")
